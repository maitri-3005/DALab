# %% [markdown]
# <a href="https://colab.research.google.com/github/maitri-3005/DALab/blob/main/DAExp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from io import StringIO
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %%
df=pd.read_csv('./sample_data/world_population.csv')

# %%
df.drop(columns=['CCA3'],inplace=True)

# %%
df=df.sort_values('Rank')
worldArea=df['Area (km²)'].sum()

# %%
head10=df.head(10)
head10
# Out:
#      Rank        Country           Capital      Continent  2022 Population  \
# 41      1          China           Beijing           Asia       1425887337
# 92      2          India         New Delhi           Asia       1417173173
# 221     3  United States  Washington, D.C.  North America        338289857
# 93      4      Indonesia           Jakarta           Asia        275501339
# 156     5       Pakistan         Islamabad           Asia        235824862
# 149     6        Nigeria             Abuja         Africa        218541212
# 27      7         Brazil          Brasilia  South America        215313498
# 16      8     Bangladesh             Dhaka           Asia        171186372
# 171     9         Russia            Moscow         Europe        144713314
# 131    10         Mexico       Mexico City  North America        127504125
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# ...

# %%
df.shape
# Out:
# (234, 16)

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.340000e+02     2.340000e+02     2.340000e+02
# mean   117.500000     3.407441e+07     3.350107e+07     3.172996e+07
# std     67.694165     1.367664e+08     1.355899e+08     1.304050e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.152845e+05     4.046760e+05
# 50%    117.500000     5.559944e+06     5.493074e+06     5.307400e+06
# 75%    175.750000     2.247650e+07     2.144798e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.340000e+02     2.340000e+02     2.340000e+02     2.340000e+02
# mean      2.984524e+07     2.626947e+07     2.271022e+07     1.898462e+07
# std       1.242185e+08     1.116982e+08     9.783217e+07     8.178519e+07
# ...

# %%
def population_graph(tail10):
    fig = go.Figure()
    for index, row in tail10.iterrows():
      y=[row['1970 Population'],row['1980 Population'],row['1990 Population'],row['2000 Population'],row['2010 Population'],row['2015 Population'],row['2020 Population'],row['2022 Population']]
      x=[1970,1980,1990,2000,2010,2015,2020,2022]
      fig.add_trace(go.Scatter(x=x, y=y, name=row['Country'],
                        line_shape='linear'))
    return fig

# %%
population_graph(df.tail(10))
# We are able to see the country wise changge in population over the years from 1970 to 2020
# For example: We can see that for the country Montserrat the population decreased drastically in the decade 1990-2000
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.corr()
# Out:
#                                  Rank  2022 Population  2020 Population  \
# Rank                         1.000000        -0.358361        -0.355854
# 2022 Population             -0.358361         1.000000         0.999946
# 2020 Population             -0.355854         0.999946         1.000000
# 2015 Population             -0.351222         0.999490         0.999763
# 2010 Population             -0.347461         0.998629         0.999105
# 2000 Population             -0.341057         0.994605         0.995583
# 1990 Population             -0.336152         0.987228         0.988724
# 1980 Population             -0.335246         0.980285         0.982121
# 1970 Population             -0.335379         0.973162         0.975254
# Area (km²)                  -0.383774         0.453411         0.454993
# Density (per km²)            0.129436        -0.027618        -0.027358
# Growth Rate                 -0.224561        -0.020863        -0.025116
# ...

# %%
sns.heatmap(df.corr())
# As we can see Area has a high correlation with all the year popluations and same is the case for World Popluation
# percentage.

# %%
p = sns.countplot(x="Continent",data = df)
_ = plt.setp(p.get_xticklabels(), rotation=90)
# We can see that in the given data most of the countries are from Africa and the least number of countries are from
# South Americas.
